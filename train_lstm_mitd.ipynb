# %%
#import matplotlib with pdf as backend
import matplotlib as plt
#matplotlib.use('PDF')
from pylab import *
#from matplotlib.backends.backend_pdf import PdfPages

import wfdb 
import os
import numpy as np
import math
import sys
import scipy.stats as st
from sklearn.preprocessing import scale
import glob, os
from os.path import basename
from functools import partial, update_wrapper
from keras import regularizers
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf
from keras.layers import Dense,Activation,Dropout
from keras.layers import LSTM,Bidirectional, GRU #could try TimeDistributed(Dense(...))
from keras.models import Sequential, load_model
from keras import optimizers,regularizers
from keras.layers.normalization import BatchNormalization
import keras.backend.tensorflow_backend as KTF
from keras.metrics import categorical_accuracy

np.random.seed(42)


def get_ecg_data_nl(datfile):
	## convert .dat/q1c to numpy arrays
	recordname=os.path.basename(datfile).split(".dat")[0]
	recordpath=os.path.dirname(datfile)
	cwd=os.getcwd()
	os.chdir(recordpath) ## somehow it only works if you chdir. 
	record = wfdb.rdsamp(recordname)
	Vctrecord=np.transpose(record.p_signals)
	Vctrecord=np.transpose(Vctrecord)
	return Vctrecord

# functions
def get_ecg_data(datfile): 
    ## convert .dat/q1c to numpy arrays
    recordname=os.path.basename(datfile).split(".dat")[0]
    recordpath=os.path.dirname(datfile)
    cwd=os.getcwd()
    os.chdir(recordpath) ## somehow it only works if you chdir. 

    annotator='atr'
    annotation = wfdb.rdann(recordname, extension=annotator, sampfrom=0,sampto = None, pbdir=None)
    record = wfdb.rdsamp(recordname, sampfrom=0,sampto = None) #wfdb.showanncodes()

    Vctrecord=np.transpose(record.p_signals)
    VctAnnotationHot=np.zeros( (2,len(Vctrecord[1])), dtype=np.int)
    VctAnnotationHot[1] = 1;
    
    #print("ecg, 2 lead of shape" , Vctrecord.shape) 
    #print("VctAnnotationHot of shape" , VctAnnotationHot.shape) 
    #print('plotting extracted signal with annotation')
    #wfdb.plotrec(record, annotation=annotation2, title='Record 100 from MIT-BIH Arrhythmia Database', timeunits = 'seconds')

    VctAnnotations=list(zip(annotation.sample,annotation.symbol)) ## zip coordinates + annotations (N),(t) etc)
    #print(VctAnnotations)
    for i in range(len(VctAnnotations)):
        if( VctAnnotations[i][1] == 'N' or 
            VctAnnotations[i][1] == 'L' or  
            VctAnnotations[i][1] == 'R' or 
           VctAnnotations[i][1] == 'B' or 
           VctAnnotations[i][1] == 'A' or
           VctAnnotations[i][1] == 'a' or 
           VctAnnotations[i][1] == 'J' or 
           VctAnnotations[i][1] == 'S' or 
           VctAnnotations[i][1] == 'V' or  
           VctAnnotations[i][1] == 'r' or  
           VctAnnotations[i][1] == 'F' or 
           VctAnnotations[i][1] == 'e' or 
           VctAnnotations[i][1] == 'j' or
           VctAnnotations[i][1] == 'n' or 
           VctAnnotations[i][1] == 'E' or 
           VctAnnotations[i][1] == '/' or 
           VctAnnotations[i][1] == 'f' or
           VctAnnotations[i][1] == 'Q' or  
           VctAnnotations[i][1] == '?'):
            VctAnnotationHot[0][VctAnnotations[i][0]] = 1;  
            VctAnnotationHot[1][VctAnnotations[i][0]] = 0;  
    VctAnnotationHot=np.transpose(VctAnnotationHot)
    Vctrecord=np.transpose(Vctrecord) # transpose to (timesteps,feat)

    os.chdir(cwd)
    return Vctrecord, VctAnnotationHot



def splitseq(x,n,o):
	n = int(n)
	o = int(o)
	#split seq; should be optimized so that remove_seq_gaps is not needed. 
	upper= int(math.ceil( x.shape[0] / n) *n)
	print("splitting on",n,"with overlap of ",o,	"total datapoints:",x.shape[0],"; upper:",upper)
	for i in range(0,upper,n):
		#print(i)
		if i==0:
			padded=np.zeros( ( o+n+o,x.shape[1])   ) ## pad with 0's on init
			padded[o:,:x.shape[1]] = x[i:i+n+o,:]
			xpart=padded
		else:
			xpart=x[i-o:i+n+o,:]
		if xpart.shape[0]<i:

			padded=np.zeros( (o+n+o,xpart.shape[1])  ) ## pad with 0's on end of seq
			padded[:xpart.shape[0],:xpart.shape[1]] = xpart
			xpart=padded

		xpart=np.expand_dims(xpart,0)## add one dimension; so that you get shape (samples,timesteps,features)
		try:
			xx=np.vstack(  (xx,xpart) )
		except UnboundLocalError: ## on init
			xx=xpart
	print("output: ",xx.shape)
	return(xx)

def remove_seq_gaps(x,y):
	#remove parts that are not annotated <- not ideal, but quickest for now.
	window=150
	c=0
	cutout=[]
	include=[]
	print("filterering.")
	print("before shape x,y",x.shape,y.shape)
	for i in range(y.shape[0]):
		
		c=c+1
		if c<window :
			include.append(i)
		if sum(y[i,0:5])>0:
			c=0 
		if c >= window:
			#print ('filtering')
			pass
	x,y=x[include,:],y[include,:]
	print(" after shape x,y",x.shape,y.shape)
	return(x,y)


def normalize_new(x):
    for i in range(x.shape[0]):
        x[i] = scale( x[i], axis=0, with_mean=True, with_std=True, copy=True )
    return x

def normalizesignal(x):
	x=st.zscore(x, ddof=0)
	return x
def normalizesignal_array(x):
	for i in range(x.shape[0]):
		x[i]=st.zscore(x[i], axis=0, ddof=0)
	return x

def plotecg(x,y,begin,end):
	#helper to plot ecg
	plt.figure(1,figsize=(11.69,8.27))
	plt.subplot(211)
	plt.plot(x[begin:end,0])
	plt.subplot(211)
	plt.plot(y[begin:end,0])
	plt.subplot(211)
	plt.plot(y[begin:end,1])
	plt.subplot(211)
	plt.plot(y[begin:end,2])
	plt.subplot(211)
	plt.plot(y[begin:end,3])
	plt.subplot(211)
	plt.plot(y[begin:end,4])
	plt.subplot(211)
	plt.plot(y[begin:end,5])

	plt.subplot(212)
	plt.plot(x[begin:end,1])
	plt.show()

def plotecg_validation(x,y_true,y_pred,begin,end):
	#helper to plot ecg
	plt.figure(1,figsize=(11.69,8.27))
	plt.subplot(211)
	plt.plot(x[begin:end,0])
	plt.subplot(211)
	plt.plot(y_pred[begin:end,0])
	plt.subplot(211)
	plt.plot(y_pred[begin:end,1])
	plt.subplot(211)
	plt.plot(y_pred[begin:end,2])
	plt.subplot(211)
	plt.plot(y_pred[begin:end,3])
	plt.subplot(211)
	plt.plot(y_pred[begin:end,4])
	plt.subplot(211)
	plt.plot(y_pred[begin:end,5])

	plt.subplot(212)
	plt.plot(x[begin:end,1])
	plt.subplot(212)
	plt.plot(y_true[begin:end,0])
	plt.subplot(212)
	plt.plot(y_true[begin:end,1])
	plt.subplot(212)
	plt.plot(y_true[begin:end,2])
	plt.subplot(212)
	plt.plot(y_true[begin:end,3])
	plt.subplot(212)
	plt.plot(y_true[begin:end,4])
	plt.subplot(212)
	plt.plot(y_true[begin:end,5])

    
def LoaddDatFiles(datfiles):  
    for datfile in datfiles:
        print(datfile)
        if basename(datfile).split(".",1)[0] in exclude:
            continue
        qf=os.path.splitext(datfile)[0]+'.atr'
        if os.path.isfile(qf):
            #print("yes",qf,datfile)
            x,y=get_ecg_data(datfile)

            x,y=splitseq(x,1000,0),splitseq(y,1000,0) ## create equal sized numpy arrays of n size and overlap of o 

            x = normalize_new(x)
            ## todo; add noise, shuffle leads etc. ?
            try: ## concat
                xx=np.vstack(  (xx,x) )
                yy=np.vstack(  (yy,y) )
            except NameError: ## if xx does not exist yet (on init)
                xx = x
                yy = y
    return(xx,yy)

def unison_shuffled_copies(a, b):
    assert len(a) == len(b)
    p = np.random.permutation(len(a))
    return a[p], b[p]

def get_session(gpu_fraction=0.8):
	#allocate % of gpu memory.
	num_threads = os.environ.get('OMP_NUM_THREADS')
	gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=gpu_fraction)
	if num_threads:
		return tf.Session(config=tf.ConfigProto(gpu_options=gpu_options, intra_op_parallelism_threads=num_threads))
	else:
		return tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))

from keras import backend as K

import numpy as np
from keras.activations import softmax
from keras.objectives import categorical_crossentropy

def weighted_categorical_crossentropy(weights):
    """
    A weighted version of keras.objectives.categorical_crossentropy
    
    Variables:
        weights: numpy array of shape (C,) where C is the number of classes
    
    Usage:
        weights = np.array([0.5,2,10]) # Class one at 0.5, class 2 twice the normal weights, class 3 10x.
        loss = weighted_categorical_crossentropy(weights)
        model.compile(loss=loss,optimizer='adam')
    """
    
    weights = K.variable(weights)
        
    def loss(y_true, y_pred):
        # scale predictions so that the class probas of each sample sum to 1
        y_pred /= K.sum(y_pred, axis=-1, keepdims=True)
        # clip to prevent NaN's and Inf's
        y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
        # calc
        loss = y_true * K.log(y_pred) * weights
        loss = -K.sum(loss, -1)
        return loss
    
    return loss

def build_model_gru():
    #data_dim = X_data.shape[2]
    #timesteps = X_data.shape[1]
    model = Sequential()
    model.add(BatchNormalization(input_shape=(seqlength, features)))  
    model.add(GRU(output_dim=50,init ='glorot_normal',
         return_sequences=True, W_regularizer=regularizers.l2(0.00),U_regularizer=regularizers.l1(0.01),dropout_W =0.2 ))
    model.add(GRU(output_dim=50,init ='glorot_normal',
        return_sequences=True,W_regularizer=regularizers.l2(0.00),U_regularizer=regularizers.l1(0.01),dropout_W =0.2))
    model.add(GRU(50,init ='glorot_normal',return_sequences=False,dropout_W =0.01, W_regularizer=regularizers.l2(0.00),U_regularizer=regularizers.l1(0.01)))
    model.add(Dense(dimout, init='glorot_normal'))
    model.add(Activation('softmax'))

    #weights = np.ones((dimout,))
    weights = np.array([0.8, 500.0])
    model.compile(loss=weighted_categorical_crossentropy(weights),optimizer='Adam')
    return model

def getmodel_simple():
    # create model
    model = Sequential()
    model.add(Dense(1000,W_regularizer=regularizers.l2(l=0.01), input_shape=(seqlength, features)))
    model.add(Dense(2000, activation='relu'))
    model.add(Dense(dimout, activation='softmax'))
    # Compile model
    weights = np.array([128., 0.1])
    adam = optimizers.adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.1)
    model.compile(loss=weighted_categorical_crossentropy(weights),optimizer=adam, metrics=['accuracy']) #(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy']) 
    return model

def getmodel():
    model = Sequential()
    model.add(Dense(32,W_regularizer=regularizers.l2(l=0.01), input_shape=(seqlength, features)))
    model.add(Bidirectional(LSTM(64, return_sequences=True)))#, input_shape=(seqlength, features)) ) ### bidirectional ---><---
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(Dense(32, activation='relu',W_regularizer=regularizers.l2(l=0.01)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(Dense(dimout, activation='softmax'))
    adam = optimizers.adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    weights = np.array([64.0, 0.1,])
    model.compile(loss=weighted_categorical_crossentropy(weights),optimizer=adam, metrics=['accuracy']) #(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy']) 
    print(model.summary())
    return(model)

def f1(y_true, y_pred):
    y_pred = K.round(y_pred)
    tp = K.sum(K.cast(y_true*y_pred, 'float'), axis=0)
    tn = K.sum(K.cast((1-y_true)*(1-y_pred), 'float'), axis=0)
    fp = K.sum(K.cast((1-y_true)*y_pred, 'float'), axis=0)
    fn = K.sum(K.cast(y_true*(1-y_pred), 'float'), axis=0)

    p = tp / (tp + fp + K.epsilon())
    r = tp / (tp + fn + K.epsilon())

    f1 = 2*p*r / (p+r+K.epsilon())
    f1 = tf.where(tf.is_nan(f1), tf.zeros_like(f1), f1)
    return K.mean(f1)

def f1_loss(y_true, y_pred):
    
    tp = K.sum(K.cast(y_true*y_pred, 'float'), axis=0)
    tn = K.sum(K.cast((1-y_true)*(1-y_pred), 'float'), axis=0)
    fp = K.sum(K.cast((1-y_true)*y_pred, 'float'), axis=0)
    fn = K.sum(K.cast(y_true*(1-y_pred), 'float'), axis=0)

    p = tp / (tp + fp + K.epsilon())
    r = tp / (tp + fn + K.epsilon())

    f1 = 2*p*r / (p+r+K.epsilon())
    f1 = tf.where(tf.is_nan(f1), tf.zeros_like(f1), f1)
    return 1 - K.mean(f1)


def getmodel_one():
    model = Sequential()
    model.add(Dense(32,W_regularizer=regularizers.l2(l=0.01), input_shape=(seqlength, features)))
    model.add(Bidirectional(LSTM(64, return_sequences=True)))#, input_shape=(seqlength, features)) ) ### bidirectional ---><---
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(Dense(32, activation='relu',W_regularizer=regularizers.l2(l=0.01)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(Dense(dimout, activation='sigmoid'))
    adam = optimizers.adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    weights = np.array([64.0, 0.1,])
    model.compile(loss=f1_loss, #loss=weighted_categorical_crossentropy(weights), 
                  optimizer=adam, 
                  metrics=['categorical_accuracy', f1_m,precision_m, recall_m]) #(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy']) 
    print(model.summary())
    return(model)


def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
## USE CPU otherwise need a lot of memory in the GPU
from keras import backend as K
import tensorflow as tf

num_cores = 4
GPU = 0
CPU = 1

if GPU:
    num_GPU = 1
    num_CPU = 6
if CPU:
    num_CPU = 7
    num_GPU = 0

config = tf.ConfigProto(intra_op_parallelism_threads=num_cores,\
        inter_op_parallelism_threads=num_cores, allow_soft_placement=True,\
        device_count = {'CPU' : num_CPU, 'GPU' : num_GPU})
session = tf.Session(config=config)
KTF.set_session(session)

# %%
# test 1 that it works the same as categorical_crossentropy with weights of one
# weights = np.ones(2)
# y_true = K.variable(xxt)
# y_pred = K.variable(yyt)
# loss_weighted=weighted_categorical_crossentropy(weights)(y_true,y_pred).eval(session=K.get_session())
# loss=categorical_crossentropy(y_true,y_pred).eval(session=K.get_session())
# np.testing.assert_almost_equal(loss_weighted,loss)
# print('OK test1')
### TESTING CATEGORICAL CROSS ENTROPY WEIGHTED
# test 2 that it works differen't than categorical_crossentropy with weights of less than one
#weights = np.array([0.1,2.5])
#loss_weighted=weighted_categorical_crossentropy(weights)(y_true,y_pred).eval(session=K.get_session())
#loss=categorical_crossentropy(y_true,y_pred).eval(session=K.get_session())
#np.testing.assert_array_less(loss_weighted,loss)
#print('OK test2')

# %%
#model =  build_model_gru() # getmodel() 
#model = getmodel()

# %%
## MITDB
import os
import wfdb

qtdbpath="/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/"#sys.argv[1] ## first argument = qtdb database from physionet. 

# load data
datfiles=glob.glob(qtdbpath+"*.dat")
datfiles
# Out:
# ['/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/102.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/114.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/105.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/210.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/230.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/209.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/109.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/208.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/122.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/119.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/112.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/213.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/203.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/222.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/118.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/108.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/219.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/205.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/201.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/215.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/214.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/234.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/220.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/103.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/221.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/207.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/117.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/115.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/104.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/124.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/228.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/233.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/121.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/107.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/111.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/123.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/232.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/106.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/101.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/202.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/212.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/217.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/116.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/223.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/113.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/231.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/100.dat',
#  '/home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/200.dat']

# %%
# load data
perct=0.81 #percentage training
percv=0.19 #percentage validation
exclude = set()
#exclude.update(["234"])# no P annotated:
datfiles=glob.glob(qtdbpath+"*.dat")

# %%
for datfile in datfiles[0:1]:
    print(datfile)
    if basename(datfile).split(".",1)[0] in exclude:
        continue
    qf=os.path.splitext(datfile)[0]+'.atr'
    if os.path.isfile(qf):
        #print("yes",qf,datfile)
        x,y=get_ecg_data(datfile)

        x,y=splitseq(x,1000,0),splitseq(y,1000,0) ## create equal sized numpy arrays of n size and overlap of o 

        x = normalize_new(x)
        ## todo; add noise, shuffle leads etc. ?
        try: ## concat
            xx=np.vstack(  (xx,x) )
            yy=np.vstack(  (yy,y) )
        except NameError: ## if xx does not exist yet (on init)
            xx = x
            yy = y
# Out:
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/102.dat
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 650000, '; upper:', 650000)
# ('output: ', (650, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 650000, '; upper:', 650000)
# ('output: ', (650, 1000, 2))

# %%
x,y=get_ecg_data(datfile)

# %%
x
# Out:
# array([[-0.2  ,  0.005],
#        [-0.2  ,  0.005],
#        [-0.2  ,  0.005],
#        ...,
#        [-0.17 ,  0.2  ],
#        [-0.195,  0.195],
#        [ 0.   ,  0.   ]])

# %%
inp_size = 1000;
xs,ys=splitseq(x,inp_size,0),splitseq(y,inp_size,0)
xs.shape
# Out:
# array([[-0.2  ,  0.005],
#        [-0.2  ,  0.005],
#        [-0.2  ,  0.005],
#        ...,
#        [-0.17 ,  0.2  ],
#        [-0.195,  0.195],
#        [ 0.   ,  0.   ]])

# %%
ys.shape
# Out:
# (650, 1000, 2)

# %%
import mpld3
mpld3.enable_notebook()
batch = 3;
subplot(2,1,1)
plot(x[batch*inp_size:(batch+1)*inp_size,:])
plot(y[batch*inp_size:(batch+1)*inp_size,:])
subplot(2,1,2)
plot(xs[batch,:,:])
plot(ys[batch,:,:])

# %%
xxt,yyt=LoaddDatFiles(datfiles[ :int(round(len(datfiles)*perct)) ]) # training data. 
xxt,yyt=unison_shuffled_copies(xxt,yyt) ### shuffle
xxv,yyv=LoaddDatFiles(datfiles[ -int(round(len(datfiles)*percv)): ] ) ## validation data.
seqlength=xxt.shape[1]
features=1#xxt.shape[2]
dimout=yyt.shape[2]
print("xxv/validation shape: {}, Seqlength: {}, Features: {}".format(xxv.shape[0],seqlength,features))
# Out:
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/102.dat
# ('first-last annotation:', 68, 649851)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649783, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649783, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/114.dat
# ('first-last annotation:', 21, 649782)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649761, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649761, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/105.dat
# ('first-last annotation:', 67, 649739)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649672, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649672, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/210.dat
# ('first-last annotation:', 13, 649961)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649948, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649948, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/230.dat
# ('first-last annotation:', 30, 649806)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649776, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649776, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/209.dat
# ('first-last annotation:', 84, 649856)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649772, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649772, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/109.dat
# ('first-last annotation:', 18, 649930)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649912, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649912, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/208.dat
# ('first-last annotation:', 9, 649934)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649925, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649925, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/122.dat
# ('first-last annotation:', 17, 649904)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649887, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649887, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/119.dat
# ('first-last annotation:', 32, 649787)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649755, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649755, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/112.dat
# ('first-last annotation:', 15, 649882)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649867, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649867, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/213.dat
# ('first-last annotation:', 18, 649991)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649973, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649973, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/203.dat
# ('first-last annotation:', 14, 649776)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649762, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649762, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/222.dat
# ('first-last annotation:', 17, 649858)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649841, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649841, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/118.dat
# ('first-last annotation:', 13, 649741)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649728, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649728, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/108.dat
# ('first-last annotation:', 23, 649768)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649745, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649745, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/219.dat
# ('first-last annotation:', 188, 649736)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649548, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649548, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/205.dat
# ('first-last annotation:', 15, 649856)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649841, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649841, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/201.dat
# ('first-last annotation:', 60, 649799)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649739, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649739, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/215.dat
# ('first-last annotation:', 41, 649874)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649833, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649833, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/214.dat
# ('first-last annotation:', 19, 649890)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649871, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649871, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/234.dat
# ('first-last annotation:', 52, 649771)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649719, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649719, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/220.dat
# ('first-last annotation:', 0, 649903)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649903, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649903, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/103.dat
# ('first-last annotation:', 21, 649874)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649853, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649853, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/221.dat
# ('first-last annotation:', 28, 649809)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649781, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649781, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/207.dat
# ('first-last annotation:', 9, 649798)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649789, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649789, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/117.dat
# ('first-last annotation:', 72, 649925)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649853, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649853, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/115.dat
# ('first-last annotation:', 44, 649954)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649910, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649910, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/104.dat
# ('first-last annotation:', 36, 649875)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649839, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649839, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/124.dat
# ('first-last annotation:', 100, 649875)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649775, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649775, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/228.dat
# ('first-last annotation:', 27, 649760)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649733, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649733, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/233.dat
# ('first-last annotation:', 3, 649945)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649942, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649942, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/121.dat
# ('first-last annotation:', 36, 649877)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649841, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649841, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/107.dat
# ('first-last annotation:', 47, 649747)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649700, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649700, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/111.dat
# ('first-last annotation:', 31, 649723)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649692, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649692, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/123.dat
# ('first-last annotation:', 25, 649688)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649663, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649663, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/232.dat
# ('first-last annotation:', 76, 649365)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649289, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649289, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/106.dat
# ('first-last annotation:', 83, 649790)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649707, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649707, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/101.dat
# ('first-last annotation:', 7, 649750)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649743, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649743, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/202.dat
# ('first-last annotation:', 183, 649876)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649693, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649693, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/212.dat
# ('first-last annotation:', 125, 649944)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649819, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649819, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/217.dat
# ('first-last annotation:', 102, 649737)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649635, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649635, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/116.dat
# ('first-last annotation:', 174, 649956)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649782, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649782, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/223.dat
# ('first-last annotation:', 96, 649848)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649752, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649752, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/113.dat
# ('first-last annotation:', 22, 649993)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649971, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649971, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/231.dat
# ('first-last annotation:', 57, 649861)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649804, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649804, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/100.dat
# ('first-last annotation:', 18, 649990)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649972, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649972, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# /home/federico/imec-nl/ECG-LSTM-Annotator/physionet/physiobank/database/mitdb/200.dat
# ('first-last annotation:', 67, 649926)
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649859, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# ('splitting on', 1000, 'with overlap of ', 0, 'total datapoints:', 649859, '; upper:', 649000)
# ('output: ', (649, 1000, 2))
# xxv/validation shape: 5841, Seqlength: 1000, Features: 1

# %%
dimout
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-25fa4db36813> in <module>()
# ----> 1 dimout
#
# NameError: name 'dimout' is not defined

# %%
i = 150
plot(xxt[i,:,0])
plot(yyt[i,:,1]+2, 'ro')

# %%
yyt.shape
# Out:
# (25311, 1000, 2)

# %%
# USE BOTH CHANNELS
pcha=xxt[:,:,1]; 
pchb=xxt[:,:,0];
#xxv[:,:,1] = xxv[:,:,0];
yyt.shape[0]*2
# Out:
# 50622

# %%
all_x = np.vstack([pcha, pchb])
all_x = np.expand_dims(all_x,2)
all_lab = np.vstack([yyt, yyt])
print(all_lab.shape)
print(all_x.shape)
# Out:
# (50622, 1000, 2)
# (50622, 1000, 1)

# %%
# call keras/tensorflow and build lstm model 
#index_ = np.linspace(0, all_x.shape[0]-1, all_x.shape[0] ).astype(int);
#shuffle(index_)

# TRAIN
KTF.set_session(session)
NUM = all_x.shape[0]
with tf.Session(): #switch to /cpu:0 to use cpu 
    #if not os.path.isfile('model_mitd_binary_noover.h5'):
    model = getmodel_one()#getmodel() #build_model_gru() 
    #model = getmodel_simple();
    for this_eps in range(10):
        model.fit(all_x[0:NUM,:,:], all_lab[0:NUM,:,:], batch_size=100, epochs=1, verbose=1) # train the model
        model.save('model_mitd_binary_noover_eps_f1loss_'+str(this_eps)+'_.h5')
        model.save_weights('model_weights_mitd_binary_noover_eps_f1loss_'+str(this_eps)+'_.h5')
# Out:
# /home/federico/venv/lib/python2.7/site-packages/ipykernel_launcher.py:351: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(32, kernel_regularizer=<keras.reg..., input_shape=(1000, 1))`
# /home/federico/venv/lib/python2.7/site-packages/ipykernel_launcher.py:355: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(32, activation="relu", kernel_regularizer=<keras.reg...)`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_49 (Dense)             (None, 1000, 32)          64
# _________________________________________________________________
# bidirectional_17 (Bidirectio (None, 1000, 128)         49664
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 1000, 128)         0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 1000, 128)         512
# _________________________________________________________________
# dense_50 (Dense)             (None, 1000, 32)          4128
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 1000, 32)          0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 1000, 32)          128
# _________________________________________________________________
# dense_51 (Dense)             (None, 1000, 2)           66
# =================================================================
# Total params: 54,562
# Trainable params: 54,242
# Non-trainable params: 320
# _________________________________________________________________
# None
# Exception tensorflow.python.framework.errors_impl.CancelledError: CancelledError() in <bound method _Callable.__del__ of <tensorflow.python.client.session._Callable object at 0x7f9f84788c90>> ignored
# Exception tensorflow.python.framework.errors_impl.CancelledError: CancelledError() in <bound method _Callable.__del__ of <tensorflow.python.client.session._Callable object at 0x7f9f83ea7a50>> ignored
# Epoch 1/1
# 50622/50622 [==============================] - 722s 14ms/step - loss: 0.5612 - categorical_accuracy: 0.9259 - f1_m: 0.9149 - precision_m: 0.8914 - recall_m: 0.9416
# Epoch 1/1
# 50622/50622 [==============================] - 719s 14ms/step - loss: 0.4328 - categorical_accuracy: 0.9898 - f1_m: 0.9903 - precision_m: 0.9847 - recall_m: 0.9960
# Epoch 1/1
# 50622/50622 [==============================] - 716s 14ms/step - loss: 0.4238 - categorical_accuracy: 0.9921 - f1_m: 0.9925 - precision_m: 0.9871 - recall_m: 0.9980
# Epoch 1/1
# 50622/50622 [==============================] - 717s 14ms/step - loss: 0.4202 - categorical_accuracy: 0.9927 - f1_m: 0.9930 - precision_m: 0.9878 - recall_m: 0.9982
# Epoch 1/1
# 50622/50622 [==============================] - 716s 14ms/step - loss: 0.4175 - categorical_accuracy: 0.9931 - f1_m: 0.9933 - precision_m: 0.9884 - recall_m: 0.9984
# Epoch 1/1
# 50622/50622 [==============================] - 716s 14ms/step - loss: 0.4157 - categorical_accuracy: 0.9933 - f1_m: 0.9935 - precision_m: 0.9888 - recall_m: 0.9983
# Epoch 1/1
# 50622/50622 [==============================] - 715s 14ms/step - loss: 0.4136 - categorical_accuracy: 0.9937 - f1_m: 0.9938 - precision_m: 0.9892 - recall_m: 0.9985
# Epoch 1/1
# 50622/50622 [==============================] - 715s 14ms/step - loss: 0.4124 - categorical_accuracy: 0.9938 - f1_m: 0.9940 - precision_m: 0.9895 - recall_m: 0.9985
# Epoch 1/1
# 50622/50622 [==============================] - 717s 14ms/step - loss: 0.4111 - categorical_accuracy: 0.9940 - f1_m: 0.9940 - precision_m: 0.9894 - recall_m: 0.9987
# Epoch 1/1
# 50622/50622 [==============================] - 715s 14ms/step - loss: 0.4112 - categorical_accuracy: 0.9940 - f1_m: 0.9941 - precision_m: 0.9895 - recall_m: 0.9988

# %%
#load weights because of the custom metrics 
from keras.models import load_model

with tf.device('/gpu:0'): #switch to /cpu:0 to use cpu 
   
    model = getmodel_one()
    model.load_weights('model_weights_mitd_binary_noover_eps_f1loss_0_.h5')


    #model = load_model('model_mitd_binary_noover_eps_mitdb_0_.h5', 
    #                   custom_objects=dependencies)    
    loss, cat_acc , f1_score, precision, recall = model.evaluate(all_x[0:NUM,:,:], all_lab[0:NUM,:,:], batch_size=100, verbose=1)
    print('f1_score: {} , CatAcc: {}, Precision: {}, Recall: {}'.format(f1_score, cat_acc,  precision, recall))

    # predict
    yy_predicted = model.predict(all_x[0:NUM,:,:]) 

    # maximize probabilities of prediction.
    for i in range(all_lab[0:NUM,:,:].shape[0]): 
        b = np.zeros_like(yy_predicted[i,:,:])
        b[np.arange(len(yy_predicted[i,:,:])), yy_predicted[i,:,:].argmax(1)] = 1
        yy_predicted[i,:,:] = b
# Out:
# /home/federico/venv/lib/python2.7/site-packages/ipykernel_launcher.py:351: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(32, kernel_regularizer=<keras.reg..., input_shape=(1000, 1))`
# /home/federico/venv/lib/python2.7/site-packages/ipykernel_launcher.py:355: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(32, activation="relu", kernel_regularizer=<keras.reg...)`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_46 (Dense)             (None, 1000, 32)          64
# _________________________________________________________________
# bidirectional_16 (Bidirectio (None, 1000, 128)         49664
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 1000, 128)         0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 1000, 128)         512
# _________________________________________________________________
# dense_47 (Dense)             (None, 1000, 32)          4128
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 1000, 32)          0
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 1000, 32)          128
# _________________________________________________________________
# dense_48 (Dense)             (None, 1000, 2)           66
# =================================================================
# Total params: 54,562
# Trainable params: 54,242
# Non-trainable params: 320
# _________________________________________________________________
# None
# 50622/50622 [==============================] - 142s 3ms/step
# f1_score: 0.987447732584 , CatAcc: 0.984981035577, Precision: 0.975842205693, Recall: 0.999364030674

# %%
# PLOT
i = 1
plt.plot(all_x[i,:,:])
plt.plot(yy_predicted[i,:,:])
# Out:
# [<matplotlib.lines.Line2D at 0x7f9f5cf600d0>,
#  <matplotlib.lines.Line2D at 0x7f9f5cf60150>]

# %%
yy_predicted = model.predict(all_x[0:2000,:,:])

# %%
from keras.layers import Dense
from keras.utils.vis_utils import plot_model

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
yyt.shape
